# %%
import pandas as pd
import numpy as np
import os

# %%
SCRIPT_DIR_PATH = os.getcwd()
OUTPUT_POSTPROCESSING_DIR_PATH = os.path.dirname(SCRIPT_DIR_PATH)
SSP_MODELING_DIR_PATH = os.path.dirname(OUTPUT_POSTPROCESSING_DIR_PATH)
SSP_OUTPUT_DIR_PATH = os.path.join(SSP_MODELING_DIR_PATH, "ssp_run_output")
CW_DATA_DIR_PATH = os.path.join(OUTPUT_POSTPROCESSING_DIR_PATH, "data")

# %%
ISO3 = "MAR"
REGION_NAME = "morocco"
RUN_DIR_PATH = os.path.join(SSP_OUTPUT_DIR_PATH, "sisepuede_results_sisepuede_run_2025-09-30T16;13;13.113881")

# %% [markdown]
# ### Load emission targets and ssp outputs dfs

# %%
# Load emission targets
emission_targets_df = pd.read_csv(os.path.join(CW_DATA_DIR_PATH, "emission_targets_morocco_2022_LULUCF_update.csv"))
emission_targets_df.head()
# Out:
#   Subsector  Gas Edgar_Sector Edgar_Subsector Edgar_Subsector_Synthetic  \
# 0      agrc  CH4  Agriculture      AG - Crops                AG - Crops
# 1      agrc  CO2  Agriculture      AG - Crops                AG - Crops
# 2      agrc  N2O  Agriculture      AG - Crops                AG - Crops
# 3      lvst  CH4  Agriculture  AG - Livestock            AG - Livestock
# 4      lsmm  CH4  Agriculture  AG - Livestock            AG - Livestock
#
#                                                 Vars                    id  \
# 0  emission_co2e_ch4_agrc_anaerobicdom_rice:emiss...      AG - Crops - CH4
# 1  emission_co2e_co2_agrc_biomass_bevs_and_spices...      AG - Crops - CO2
# 2  emission_co2e_n2o_agrc_biomass_burning:emissio...      AG - Crops - N2O
# 3  emission_co2e_ch4_lvst_entferm_buffalo:emissio...  AG - Livestock - CH4
# 4  emission_co2e_ch4_lsmm_anaerobic_digester:emis...  AG - Livestock - CH4
#
#         MAR         Edgar_Class
# 0  0.026607      AG - Crops:CH4
# 1  0.611888      AG - Crops:CO2
# 2  4.621083      AG - Crops:N2O
# 3  4.577545  AG - Livestock:CH4
# 4  4.577545  AG - Livestock:CH4

# %%
# Load output data
ssp_output_df = pd.read_csv(os.path.join(RUN_DIR_PATH, 
                                         "sisepuede_results_sisepuede_run_2025-09-30T16;13;13.113881_WIDE_INPUTS_OUTPUTS.csv"))
ssp_output_df.head()
# Out:
#    primary_id   region  time_period  area_agrc_crops_bevs_and_spices  \
# 0           0  morocco            0                              0.0
# 1           0  morocco            1                              0.0
# 2           0  morocco            2                              0.0
# 3           0  morocco            3                              0.0
# 4           0  morocco            4                              0.0
#
#    area_agrc_crops_cereals  area_agrc_crops_fibers  area_agrc_crops_fruits  \
# 0             4.609331e+06             4085.468561            1.190441e+06
# 1             4.560555e+06             4042.236066            1.177843e+06
# 2             4.672405e+06             4141.374219            1.206731e+06
# 3             4.759936e+06             4218.957338            1.229337e+06
# 4             4.709498e+06             4174.251507            1.216311e+06
#
#    area_agrc_crops_herbs_and_other_perennial_crops  area_agrc_crops_nuts  \
# 0                                     28242.323335         152999.613918
# 1                                     27943.462606         151380.569494
# 2                                     28628.792023         155093.264619
# 3                                     29165.114227         157998.729910
# 4                                     28856.068519         156324.509507
#
#    area_agrc_crops_other_annual  ...  \
# 0                 950343.230957  ...
# 1                 940286.683299  ...
# 2                 963347.752475  ...
# 3                 981394.786726  ...
# 4                 970995.518476  ...
#
#    yf_agrc_herbs_and_other_perennial_crops_tonne_ha  yf_agrc_nuts_tonne_ha  \
# 0                                         12.059233               2.946800
# 1                                         12.539800               3.455483
# 2                                         12.161233               3.041817
# 3                                         12.289167               3.375283
# 4                                         12.337700               2.992183
#
#    yf_agrc_other_annual_tonne_ha  yf_agrc_other_woody_perennial_tonne_ha  \
# 0                       6.177415                                     0.0
# 1                       7.165802                                     0.0
# 2                      11.119348                                     0.0
# 3                       5.436126                                     0.0
# 4                       6.177415                                     0.0
#
#    yf_agrc_pulses_tonne_ha  yf_agrc_rice_tonne_ha  \
# 0                 2.755621               8.636027
# 1                 3.259699               8.228317
# 2                 3.958685               8.302446
# 3                 4.167037               8.846059
# 4                 3.226093               7.882382
#
#    yf_agrc_sugar_cane_tonne_ha  yf_agrc_tubers_tonne_ha  \
# 0                    73.140598                37.547100
# 1                    71.163825                39.000100
# 2                    89.448975                39.119475
# 3                    90.190264                37.352525
# 4                    84.012849                38.551850
#
#    yf_agrc_vegetables_and_vines_tonne_ha  \
# 0                              28.821448
# 1                              29.765171
# 2                              28.720595
# 3                              29.482348
# 4                              32.769776
#
#    yf_lndu_supremum_pastures_tonne_per_ha
# 0                                   92.81
# 1                                   92.81
# 2                                   92.81
# 3                                   92.81
# 4                                   92.81
#
# [5 rows x 4054 columns]

# %% [markdown]
# ### Obtain the ssp output values in the emission targets format

# %%
def sum_vars_from_ssp_outputs(
    emission_targets_df: pd.DataFrame,
    ssp_outputs_df: pd.DataFrame,
    vars_col: str = "Vars",
    out_col: str = "ssp_total",
    record_missing_col: str | None = "missing_vars",
    ssp_filter: dict | None = None,
) -> pd.DataFrame:
    """
    For each row in emission_targets_df, split the colon-separated strings in `vars_col`,
    find those columns in ssp_outputs_df, sum their values (over rows & columns), and
    write the total to `out_col` in emission_targets_df.

    Parameters
    ----------
    emission_targets_df : DataFrame
        Must contain a string column `vars_col` with colon-separated names.
    ssp_outputs_df : DataFrame
        Wide table whose columns include the names referenced by `emission_targets_df[vars_col]`.
    vars_col : str
        Column in emission_targets_df with colon-separated variable names.
    out_col : str
        New column to create in emission_targets_df with totals from ssp_outputs_df.
    record_missing_col : str | None
        If provided, creates a column listing any missing vars for each row.
    df2_filter : dict | None
        Optional filters to reduce ssp_outputs_df before summing, e.g.
        {"region": "egypt", "time_period": 7}

    Returns
    -------
    DataFrame
        emission_targets_df with new column `out_col` (and `record_missing_col` if requested).
    """
    # Optionally filter ssp_outputs_df by key=value pairs (e.g., region/time_period)
    if ssp_filter:
        mask = pd.Series(True, index=ssp_outputs_df.index)
        for k, v in ssp_filter.items():
            mask &= (ssp_outputs_df[k] == v)
        ssp_view = ssp_outputs_df.loc[mask]
    else:
        ssp_view = ssp_outputs_df

    # Ensure we only operate on numeric data when summing
    numeric_cols = set(ssp_view.select_dtypes(include=[np.number]).columns)

    def _total_for_vars(vars_str: str):
        if pd.isna(vars_str) or not str(vars_str).strip():
            return np.nan, []

        # Split, strip, and deduplicate while preserving order
        raw = [s.strip() for s in str(vars_str).split(":") if s.strip()]
        seen = set()
        cols = [c for c in raw if not (c in seen or seen.add(c))]

        present = [c for c in cols if c in ssp_view.columns and c in numeric_cols]
        missing = [c for c in cols if c not in ssp_view.columns or c not in numeric_cols]

        if not present or ssp_view.empty:
            return np.nan, missing

        # Sum over all filtered rows & all present columns
        vals = ssp_view[present].to_numpy(dtype=float, copy=False)
        total = np.nansum(vals)
        return float(total), missing

    totals, missings = [], []
    for v in emission_targets_df[vars_col].astype("string"):
        total, missing = _total_for_vars(v)
        totals.append(total)
        missings.append(missing)

    emission_targets_df = emission_targets_df.copy()
    emission_targets_df[out_col] = totals
    if record_missing_col is not None:
        emission_targets_df[record_missing_col] = missings

    return emission_targets_df


# -----------------------------
# Example usage
# -----------------------------

# If DF2 has a single row for the target (e.g., region="egypt", a specific time_period):
# df2_filter = {"region": "egypt"}              # or {"region": "egypt", "time_period": 7}
# If you want to sum across all rows of DF2, set df2_filter = None.

# df1_result = sum_vars_from_df2(DF1, DF2, vars_col="Vars",
#                                out_col="DF2_total",
#                                record_missing_col="Missing_in_DF2",
#                                df2_filter={"region": "egypt"})
# print(df1_result.head())

# %%
ssp_output_df.head()
# Out:
#    primary_id   region  time_period  area_agrc_crops_bevs_and_spices  \
# 0           0  morocco            0                              0.0
# 1           0  morocco            1                              0.0
# 2           0  morocco            2                              0.0
# 3           0  morocco            3                              0.0
# 4           0  morocco            4                              0.0
#
#    area_agrc_crops_cereals  area_agrc_crops_fibers  area_agrc_crops_fruits  \
# 0             4.609331e+06             4085.468561            1.190441e+06
# 1             4.560555e+06             4042.236066            1.177843e+06
# 2             4.672405e+06             4141.374219            1.206731e+06
# 3             4.759936e+06             4218.957338            1.229337e+06
# 4             4.709498e+06             4174.251507            1.216311e+06
#
#    area_agrc_crops_herbs_and_other_perennial_crops  area_agrc_crops_nuts  \
# 0                                     28242.323335         152999.613918
# 1                                     27943.462606         151380.569494
# 2                                     28628.792023         155093.264619
# 3                                     29165.114227         157998.729910
# 4                                     28856.068519         156324.509507
#
#    area_agrc_crops_other_annual  ...  \
# 0                 950343.230957  ...
# 1                 940286.683299  ...
# 2                 963347.752475  ...
# 3                 981394.786726  ...
# 4                 970995.518476  ...
#
#    yf_agrc_herbs_and_other_perennial_crops_tonne_ha  yf_agrc_nuts_tonne_ha  \
# 0                                         12.059233               2.946800
# 1                                         12.539800               3.455483
# 2                                         12.161233               3.041817
# 3                                         12.289167               3.375283
# 4                                         12.337700               2.992183
#
#    yf_agrc_other_annual_tonne_ha  yf_agrc_other_woody_perennial_tonne_ha  \
# 0                       6.177415                                     0.0
# 1                       7.165802                                     0.0
# 2                      11.119348                                     0.0
# 3                       5.436126                                     0.0
# 4                       6.177415                                     0.0
#
#    yf_agrc_pulses_tonne_ha  yf_agrc_rice_tonne_ha  \
# 0                 2.755621               8.636027
# 1                 3.259699               8.228317
# 2                 3.958685               8.302446
# 3                 4.167037               8.846059
# 4                 3.226093               7.882382
#
#    yf_agrc_sugar_cane_tonne_ha  yf_agrc_tubers_tonne_ha  \
# 0                    73.140598                37.547100
# 1                    71.163825                39.000100
# 2                    89.448975                39.119475
# 3                    90.190264                37.352525
# 4                    84.012849                38.551850
#
#    yf_agrc_vegetables_and_vines_tonne_ha  \
# 0                              28.821448
# 1                              29.765171
# 2                              28.720595
# 3                              29.482348
# 4                              32.769776
#
#    yf_lndu_supremum_pastures_tonne_per_ha
# 0                                   92.81
# 1                                   92.81
# 2                                   92.81
# 3                                   92.81
# 4                                   92.81
#
# [5 rows x 4054 columns]

# %%
emission_targets_df_extended = sum_vars_from_ssp_outputs(emission_targets_df, ssp_output_df, vars_col="Vars",
                               out_col="ssp_emission",
                               record_missing_col="missing_in_ssp_outputs",
                               ssp_filter={"region": REGION_NAME, "primary_id": 0, "time_period": 7})

emission_targets_df_extended.head()
# Out:
#   Subsector  Gas Edgar_Sector Edgar_Subsector Edgar_Subsector_Synthetic  \
# 0      agrc  CH4  Agriculture      AG - Crops                AG - Crops
# 1      agrc  CO2  Agriculture      AG - Crops                AG - Crops
# 2      agrc  N2O  Agriculture      AG - Crops                AG - Crops
# 3      lvst  CH4  Agriculture  AG - Livestock            AG - Livestock
# 4      lsmm  CH4  Agriculture  AG - Livestock            AG - Livestock
#
#                                                 Vars                    id  \
# 0  emission_co2e_ch4_agrc_anaerobicdom_rice:emiss...      AG - Crops - CH4
# 1  emission_co2e_co2_agrc_biomass_bevs_and_spices...      AG - Crops - CO2
# 2  emission_co2e_n2o_agrc_biomass_burning:emissio...      AG - Crops - N2O
# 3  emission_co2e_ch4_lvst_entferm_buffalo:emissio...  AG - Livestock - CH4
# 4  emission_co2e_ch4_lsmm_anaerobic_digester:emis...  AG - Livestock - CH4
#
#         MAR         Edgar_Class  ssp_emission missing_in_ssp_outputs
# 0  0.026607      AG - Crops:CH4      0.195274                     []
# 1  0.611888      AG - Crops:CO2      0.211910                     []
# 2  4.621083      AG - Crops:N2O      2.332593                     []
# 3  4.577545  AG - Livestock:CH4      1.073324                     []
# 4  4.577545  AG - Livestock:CH4      0.181252                     []

# %% [markdown]
# ### Create diff report

# %%
# subset the emission targets to create the diff report template
diff_report_df = emission_targets_df_extended[[
    "Subsector",
    "id",
    ISO3,
    "ssp_emission",
]].copy()
diff_report_df.head()
# Out:
#   Subsector                    id       MAR  ssp_emission
# 0      agrc      AG - Crops - CH4  0.026607      0.195274
# 1      agrc      AG - Crops - CO2  0.611888      0.211910
# 2      agrc      AG - Crops - N2O  4.621083      2.332593
# 3      lvst  AG - Livestock - CH4  4.577545      1.073324
# 4      lsmm  AG - Livestock - CH4  4.577545      0.181252

# %%
# merge subsector an id into a single column for clarity
diff_report_df["subsector_id"] = diff_report_df["Subsector"] + " - " + diff_report_df["id"]
diff_report_df = diff_report_df.drop(columns=["Subsector", "id"])
diff_report_df.head()
# Out:
#         MAR  ssp_emission                 subsector_id
# 0  0.026607      0.195274      agrc - AG - Crops - CH4
# 1  0.611888      0.211910      agrc - AG - Crops - CO2
# 2  4.621083      2.332593      agrc - AG - Crops - N2O
# 3  4.577545      1.073324  lvst - AG - Livestock - CH4
# 4  4.577545      0.181252  lsmm - AG - Livestock - CH4

# %%
#rename region column
diff_report_df = diff_report_df.rename(columns={ISO3: "inventory_emission"})
diff_report_df.head()
# Out:
#    inventory_emission  ssp_emission                 subsector_id
# 0            0.026607      0.195274      agrc - AG - Crops - CH4
# 1            0.611888      0.211910      agrc - AG - Crops - CO2
# 2            4.621083      2.332593      agrc - AG - Crops - N2O
# 3            4.577545      1.073324  lvst - AG - Livestock - CH4
# 4            4.577545      0.181252  lsmm - AG - Livestock - CH4

# %%
# Create inventory_share column
diff_report_df["inventory_share"] = diff_report_df["inventory_emission"] / diff_report_df["inventory_emission"].sum()
diff_report_df
# Out:
#     inventory_emission  ssp_emission  \
# 0             0.026607      0.195274
# 1             0.611888      0.211910
# 2             4.621083      2.332593
# 3             4.577545      1.073324
# 4             4.577545      0.181252
# 5             0.061910      0.162365
# 6             0.000000      0.000000
# 7             0.000000      0.000000
# 8             0.000000      0.000000
# 9             0.415829      0.003007
# 10           12.215620      4.756340
# 11            0.326524      0.003464
# 12            0.006022      0.045412
# 13           27.519878     15.472820
# 14            0.104689      0.041351
# 15            0.170801      3.777596
# 16            0.014851      3.335980
# 17            0.000734      0.005092
# 18            0.010545      0.033081
# 19            7.559506      6.153044
# 20            0.017397      0.051768
# 21            0.000000      0.000000
# 22            0.000000      0.000000
# 23            0.000000      0.000000
# 24            0.073646      0.210661
# 25           19.366701     44.846694
# 26            0.253538      0.827560
# 27            0.000000      0.000000
# 28            5.353567      0.034804
# 29            1.817981      2.990846
# 30            0.462577      0.083931
# 31            0.000000      0.000013
# 32            0.000000      0.056343
# 33            0.000000      0.280166
# 34            0.011666      0.011666
# 35            4.545796      4.545796
# 36            0.162925      0.162925
# 37            0.000000     10.137287
# 38           -0.875000    -12.049629
# 39            0.000000     -2.426299
# 40            3.097110      3.097110
# 41           17.205768     17.205768
# 42            0.000000     -2.279446
# 43            0.000000      0.000012
# 44           18.920253      0.100174
# 45            0.000000      2.265525
# 46            0.006684      0.013684
# 47            5.047132      1.063282
# 48            0.629650      0.377888
#
#                                        subsector_id  inventory_share
# 0                           agrc - AG - Crops - CH4         0.000192
# 1                           agrc - AG - Crops - CO2         0.004405
# 2                           agrc - AG - Crops - N2O         0.033265
# 3                       lvst - AG - Livestock - CH4         0.032951
# 4                       lsmm - AG - Livestock - CH4         0.032951
# 5                       lsmm - AG - Livestock - N2O         0.000446
# 6                                 ccsq - CCSQ - CH4         0.000000
# 7                                 ccsq - CCSQ - CO2         0.000000
# 8                                 ccsq - CCSQ - N2O         0.000000
# 9                        scoe - EN - Building - CH4         0.002993
# 10                       scoe - EN - Building - CO2         0.087933
# 11                       scoe - EN - Building - N2O         0.002350
# 12               entc - EN - Electricity/Heat - CH4         0.000043
# 13               entc - EN - Electricity/Heat - CO2         0.198100
# 14               entc - EN - Electricity/Heat - N2O         0.000754
# 15             fgtv - EN - Fugitive Emissions - CH4         0.001229
# 16             fgtv - EN - Fugitive Emissions - CO2         0.000107
# 17             fgtv - EN - Fugitive Emissions - N2O         0.000005
# 18     inen - EN - Manufacturing/Construction - CH4         0.000076
# 19     inen - EN - Manufacturing/Construction - CO2         0.054417
# 20     inen - EN - Manufacturing/Construction - N2O         0.000125
# 21                          scoe - EN - Other - CH4         0.000000
# 22                          scoe - EN - Other - CO2         0.000000
# 23                          scoe - EN - Other - N2O         0.000000
# 24                 trns - EN - Transportation - CH4         0.000530
# 25                 trns - EN - Transportation - CO2         0.139410
# 26                 trns - EN - Transportation - N2O         0.001825
# 27           ippu - IN - Industrial Processes - CH4         0.000000
# 28           ippu - IN - Industrial Processes - CO2         0.038537
# 29           ippu - IN - Industrial Processes - HFC         0.013087
# 30           ippu - IN - Industrial Processes - N2O         0.003330
# 31     ippu - IN - Industrial Processes - OTHER_FCS         0.000000
# 32           ippu - IN - Industrial Processes - PFC         0.000000
# 33           ippu - IN - Industrial Processes - SF6         0.000000
# 34              lndu - LULUCF - Deforestation - CH4         0.000084
# 35              lndu - LULUCF - Deforestation - CO2         0.032723
# 36                frst - LULUCF - Forest Land - CH4         0.001173
# 37       frst - LULUCF - Forest Land Removals - CO2         0.000000
# 38  frst - LULUCF - Forest Land Sequestration - CO2        -0.006299
# 39                        frst - LULUCF - HWP - CO2         0.000000
# 40               soil - LULUCF - Organic Soil - CO2         0.022294
# 41               soil - LULUCF - Organic Soil - N2O         0.123855
# 42                 lndu - LULUCF - Other Land - CO2         0.000000
# 43                         ippu - UNACCOUNTED - NF3         0.000000
# 44                 waso - Waste - Solid Waste - CH4         0.136196
# 45                 waso - Waste - Solid Waste - CO2         0.000000
# 46                 waso - Waste - Solid Waste - N2O         0.000048
# 47        trww - Waste - Wastewater Treatment - CH4         0.036331
# 48        trww - Waste - Wastewater Treatment - N2O         0.004532

# %%
# Calculate error column, avoid division by zero by adding a small constant to the denominator
epsilon = 1e-8
diff_report_df["error"] = (diff_report_df["ssp_emission"] - diff_report_df["inventory_emission"]).abs() / (diff_report_df["inventory_emission"] + epsilon)
diff_report_df["squared_error"] = (diff_report_df["error"] ** 2)
diff_report_df.head()
# Out:
#    inventory_emission  ssp_emission                 subsector_id  \
# 0            0.026607      0.195274      agrc - AG - Crops - CH4
# 1            0.611888      0.211910      agrc - AG - Crops - CO2
# 2            4.621083      2.332593      agrc - AG - Crops - N2O
# 3            4.577545      1.073324  lvst - AG - Livestock - CH4
# 4            4.577545      0.181252  lsmm - AG - Livestock - CH4
#
#    inventory_share     error  squared_error
# 0         0.000192  6.339291      40.186616
# 1         0.004405  0.653678       0.427295
# 2         0.033265  0.495228       0.245251
# 3         0.032951  0.765524       0.586027
# 4         0.032951  0.960404       0.922376

# %%
# Set subsector_id at the beginning of the df
diff_report_df = diff_report_df[[
    "subsector_id",
    "inventory_emission",
    "ssp_emission",
    "inventory_share",
    "error",
    "squared_error"
]]

# sort by squared_error descending
diff_report_df = diff_report_df.sort_values(by="squared_error", ascending=False)
diff_report_df.head(10)
# Out:
#                                     subsector_id  inventory_emission  \
# 37    frst - LULUCF - Forest Land Removals - CO2            0.000000
# 39                     frst - LULUCF - HWP - CO2            0.000000
# 42              lndu - LULUCF - Other Land - CO2            0.000000
# 45              waso - Waste - Solid Waste - CO2            0.000000
# 33        ippu - IN - Industrial Processes - SF6            0.000000
# 32        ippu - IN - Industrial Processes - PFC            0.000000
# 31  ippu - IN - Industrial Processes - OTHER_FCS            0.000000
# 43                      ippu - UNACCOUNTED - NF3            0.000000
# 16          fgtv - EN - Fugitive Emissions - CO2            0.014851
# 15          fgtv - EN - Fugitive Emissions - CH4            0.170801
#
#     ssp_emission  inventory_share         error  squared_error
# 37     10.137287         0.000000  1.013729e+09   1.027646e+18
# 39     -2.426299         0.000000  2.426299e+08   5.886927e+16
# 42     -2.279446         0.000000  2.279446e+08   5.195876e+16
# 45      2.265525         0.000000  2.265525e+08   5.132605e+16
# 33      0.280166         0.000000  2.801658e+07   7.849285e+14
# 32      0.056343         0.000000  5.634252e+06   3.174479e+13
# 31      0.000013         0.000000  1.342789e+03   1.803083e+06
# 43      0.000012         0.000000  1.217753e+03   1.482922e+06
# 16      3.335980         0.000107  2.236305e+02   5.001059e+04
# 15      3.777596         0.001229  2.111700e+01   4.459279e+02

# %%
diff_report_df.tail(40)
# Out:
#                                        subsector_id  inventory_emission  \
# 15             fgtv - EN - Fugitive Emissions - CH4            0.170801
# 38  frst - LULUCF - Forest Land Sequestration - CO2           -0.875000
# 12               entc - EN - Electricity/Heat - CH4            0.006022
# 0                           agrc - AG - Crops - CH4            0.026607
# 17             fgtv - EN - Fugitive Emissions - N2O            0.000734
# 26                 trns - EN - Transportation - N2O            0.253538
# 18     inen - EN - Manufacturing/Construction - CH4            0.010545
# 20     inen - EN - Manufacturing/Construction - N2O            0.017397
# 24                 trns - EN - Transportation - CH4            0.073646
# 5                       lsmm - AG - Livestock - N2O            0.061910
# 25                 trns - EN - Transportation - CO2           19.366701
# 46                 waso - Waste - Solid Waste - N2O            0.006684
# 44                 waso - Waste - Solid Waste - CH4           18.920253
# 28           ippu - IN - Industrial Processes - CO2            5.353567
# 9                        scoe - EN - Building - CH4            0.415829
# 11                       scoe - EN - Building - N2O            0.326524
# 4                       lsmm - AG - Livestock - CH4            4.577545
# 30           ippu - IN - Industrial Processes - N2O            0.462577
# 47        trww - Waste - Wastewater Treatment - CH4            5.047132
# 3                       lvst - AG - Livestock - CH4            4.577545
# 1                           agrc - AG - Crops - CO2            0.611888
# 29           ippu - IN - Industrial Processes - HFC            1.817981
# 10                       scoe - EN - Building - CO2           12.215620
# 14               entc - EN - Electricity/Heat - N2O            0.104689
# 2                           agrc - AG - Crops - N2O            4.621083
# 13               entc - EN - Electricity/Heat - CO2           27.519878
# 48        trww - Waste - Wastewater Treatment - N2O            0.629650
# 19     inen - EN - Manufacturing/Construction - CO2            7.559506
# 34              lndu - LULUCF - Deforestation - CH4            0.011666
# 36                frst - LULUCF - Forest Land - CH4            0.162925
# 41               soil - LULUCF - Organic Soil - N2O           17.205768
# 40               soil - LULUCF - Organic Soil - CO2            3.097110
# 35              lndu - LULUCF - Deforestation - CO2            4.545796
# 7                                 ccsq - CCSQ - CO2            0.000000
# 6                                 ccsq - CCSQ - CH4            0.000000
# 27           ippu - IN - Industrial Processes - CH4            0.000000
# 23                          scoe - EN - Other - N2O            0.000000
# 22                          scoe - EN - Other - CO2            0.000000
# 21                          scoe - EN - Other - CH4            0.000000
# 8                                 ccsq - CCSQ - N2O            0.000000
#
#     ssp_emission  inventory_share         error  squared_error
# 15      3.777596         0.001229  2.111700e+01   4.459279e+02
# 38    -12.049629        -0.006299 -1.277100e+01   1.630986e+02
# 12      0.045412         0.000043  6.540715e+00   4.278095e+01
# 0       0.195274         0.000192  6.339291e+00   4.018662e+01
# 17      0.005092         0.000005  5.937658e+00   3.525578e+01
# 26      0.827560         0.001825  2.264051e+00   5.125927e+00
# 18      0.033081         0.000076  2.137106e+00   4.567222e+00
# 20      0.051768         0.000125  1.975593e+00   3.902970e+00
# 24      0.210661         0.000530  1.860442e+00   3.461245e+00
# 5       0.162365         0.000446  1.622582e+00   2.632773e+00
# 25     44.846694         0.139410  1.315660e+00   1.730961e+00
# 46      0.013684         0.000048  1.047166e+00   1.096556e+00
# 44      0.100174         0.136196  9.947054e-01   9.894389e-01
# 28      0.034804         0.038537  9.934989e-01   9.870400e-01
# 9       0.003007         0.002993  9.927694e-01   9.855912e-01
# 11      0.003464         0.002350  9.893915e-01   9.788956e-01
# 4       0.181252         0.032951  9.604041e-01   9.223761e-01
# 30      0.083931         0.003330  8.185574e-01   6.700362e-01
# 47      1.063282         0.036331  7.893295e-01   6.230411e-01
# 3       1.073324         0.032951  7.655240e-01   5.860270e-01
# 1       0.211910         0.004405  6.536780e-01   4.272949e-01
# 29      2.990846         0.013087  6.451470e-01   4.162147e-01
# 10      4.756340         0.087933  6.106346e-01   3.728746e-01
# 14      0.041351         0.000754  6.050152e-01   3.660434e-01
# 2       2.332593         0.033265  4.952281e-01   2.452509e-01
# 13     15.472820         0.198100  4.377584e-01   1.916324e-01
# 48      0.377888         0.004532  3.998444e-01   1.598756e-01
# 19      6.153044         0.054417  1.860521e-01   3.461537e-02
# 34      0.011666         0.000084  3.546573e-08   1.257818e-15
# 36      0.162925         0.001173  1.335026e-09   1.782293e-18
# 41     17.205768         0.123855  2.141333e-10   4.585306e-20
# 40      3.097110         0.022294  9.111952e-11   8.302767e-21
# 35      4.545796         0.032723  6.128433e-11   3.755769e-21
# 7       0.000000         0.000000  0.000000e+00   0.000000e+00
# 6       0.000000         0.000000  0.000000e+00   0.000000e+00
# 27      0.000000         0.000000  0.000000e+00   0.000000e+00
# 23      0.000000         0.000000  0.000000e+00   0.000000e+00
# 22      0.000000         0.000000  0.000000e+00   0.000000e+00
# 21      0.000000         0.000000  0.000000e+00   0.000000e+00
# 8       0.000000         0.000000  0.000000e+00   0.000000e+00

# %% [markdown]
# ### Save diff table

# %%
diff_report_df.to_csv(os.path.join(RUN_DIR_PATH, f"diff_report_{REGION_NAME}.csv"), index=False)
